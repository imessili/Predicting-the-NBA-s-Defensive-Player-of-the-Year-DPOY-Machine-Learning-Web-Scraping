# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import pearsonr

# %%
def show_PersonsR(Data_set, year_data):

    All_players_dataSet = Data_set.copy()

    All_players_dataSet = All_players_dataSet.drop(columns=All_players_dataSet.columns[All_players_dataSet.columns.str.contains('Unnamed:')])
    All_players_dataSet.reset_index(drop=True, inplace=True)
    
    All_players_dataSet.fillna(0, inplace=True)
    All_players_dataSet.replace('', 0, inplace=True)
    All_players_dataSet.replace('--', 0, inplace=True)
    
    # check if any NaN,empty Strings exists in the dataframe
    any_missing_values = All_players_dataSet.isna().any().any()
    any_empty_values = (All_players_dataSet.applymap(lambda x: x == '')).any().any()
    if any_missing_values or any_empty_values:
        print("DataFrame contains missing values or empty strings/spaces.")
    else:
        print("DataFrame does not contain missing values or empty strings/spaces.")

    # Drop unwanted columns
    columns_to_drop = ['First_votes', 'Season', 'Year', 'Player_name', 'won_dpoy_last_season',
                   'Max_points', 'Tm', 'Lg', 'Pos', 'Rank', 'Arena_misc',
                   'Attendance_misc','FG', 'FGA', 'FG%', '3P', '3PA',
                   '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'AST',
                   'PTS', 'FG_100_poss', 'FGA_100_poss', 'FG%_100_poss',
                   '3P_100_poss', '3PA_100_poss', '3P%_100_poss', '2P_100_poss', '2PA_100_poss',
                   '2P%_100_poss', 'FT_100_poss', 'FTA_100_poss', 'FT%_100_poss', 'ORB_100_poss', 'AST_100_poss',
                   'PTS_100_poss', 'ORtg_100_poss', '3PAr_advanced', 'FTr_advanced', 'ORB%_advanced',
                   'OWS_advanced', 'OBPM_advanced', 'AST%_advanced', 'USG%_advanced', 'G_team', 'MP_team', 'FG_team', 'FGA_team',
                   'FG%_team', '3P_team', '3PA_team', '3P%_team', '2P_team', '2PA_team', '2P%_team',
                   'FT_team', 'FTA_team', 'FT%_team', 'ORB_team', 'G_opponent', 'MP_opponent',
                   'FG_opponent', 'STL_opponent', 'BLK_opponent','DRB_opponent', 'TOV_opponent', 'PF_opponent',
                   'PTS_opponent', 'ORtg_misc', 'FTr_misc', '3PAr_misc', 'eFG%_misc', 'ORB%_misc',
                   'FT/FGA_misc', 'eFG%.1_misc', 'FT/FGA.1_misc', 'ORPM_espn', 'raptor_offense_raptor',
                   'war_playoffs_raptor', 'predator_offense_raptor','FTr_misc','FT/FGA.1_misc','BLK_opponent',
                   '3P_team','FT/FGA.1_misc', 'PTS_team','TS%_advanced','L_nba','TOV%_advanced']

    All_players_dataSet['won_dpoy_last_season'] = All_players_dataSet['won_dpoy_last_season'].astype(int)
    
    ## Drop the specified columns
    All_players_dataSet.drop(columns=columns_to_drop, inplace=True)
    
    ## seperating our dataFrame
    Y = All_players_dataSet['Points_won']  # Target
    X = All_players_dataSet.drop('Points_won', axis=1)  # Features
    

    X = X.apply(pd.to_numeric, errors='coerce')

    ##Pearson’s R
    ## 1 indicates a perfect positive linear relationship,
    ## -1 indicates a perfect negative linear relationship, and
    ## 0 indicates no linear correlation.
    ## The p-value is a measure in statistical hypothesis testing
    ## that quantifies the evidence against a null hypothesis,
    ## with a lower p-value suggesting stronger evidence to reject the null hypothesis.
    
    correlation_data = {}
    for column in X.columns:
        corr_coefficient, p_value = pearsonr(X[column], Y)
        correlation_data[column] = {'correlation': corr_coefficient, 'p-value': p_value}
        
    # Sort the features based on the absolute correlation coefficient
    sorted_features = sorted(correlation_data.items(), key=lambda x: abs(x[1]['correlation']), reverse=True)

    # Create a DataFrame from the correlation_data dictionary
    correlation_df = pd.DataFrame.from_dict(correlation_data, orient='index')
    correlation_df.index.name = 'Feature'

    # Sort the DataFrame based on the absolute correlation coefficient
    correlation_df = correlation_df.reindex(correlation_df['correlation'].abs().sort_values(ascending=False).index)

    top_100_features_df = correlation_df.head(100)
    
    # Save the DataFrame to a CSV file
    top_100_features_df.to_csv('top_N_features_PersonsR{}.csv'.format(year_data))
    
    for feature, data in sorted_features:
        print(f"Pearson correlation coefficient for {feature}: {data['correlation']:.3f}, p-value: {data['p-value']:.3f}")

# %%
all_players_w_add_sorted = pd.read_csv("all_players_w_add_sorted.csv")
show_PersonsR(all_players_w_add_sorted, "All")
# Out:
# C:\Users\Abdou\AppData\Local\Temp\ipykernel_9968\200196506.py:1: DtypeWarning: Columns (154,155) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_players_w_add_sorted = pd.read_csv("all_players_w_add_sorted.csv")
# DataFrame does not contain missing values or empty strings/spaces.
# Pearson correlation coefficient for Dpoy_titles: 0.290, p-value: 0.000
# Pearson correlation coefficient for DWS_advanced: 0.248, p-value: 0.000
# Pearson correlation coefficient for Dpoy_votes: 0.235, p-value: 0.000
# Pearson correlation coefficient for BLK_nba: 0.234, p-value: 0.000
# Pearson correlation coefficient for war_total_raptor: 0.226, p-value: 0.000
# Pearson correlation coefficient for BLK: 0.217, p-value: 0.000
# Pearson correlation coefficient for WINS_espn: 0.212, p-value: 0.000
# Pearson correlation coefficient for war_reg_season_raptor: 0.210, p-value: 0.000
# Pearson correlation coefficient for VORP_advanced: 0.204, p-value: 0.000
# Pearson correlation coefficient for WS_advanced: 0.196, p-value: 0.000
# Pearson correlation coefficient for D-LEBRON_bball: 0.194, p-value: 0.000
# Pearson correlation coefficient for DREB_nba: 0.186, p-value: 0.000
# Pearson correlation coefficient for DRB: 0.183, p-value: 0.000
# Pearson correlation coefficient for TRB: 0.175, p-value: 0.000
# Pearson correlation coefficient for DEF WS_nba: 0.170, p-value: 0.000
# Pearson correlation coefficient for DRPM_espn: 0.159, p-value: 0.000
# Pearson correlation coefficient for RPM_espn: 0.152, p-value: 0.000
# Pearson correlation coefficient for predator_defense_raptor: 0.132, p-value: 0.000
# Pearson correlation coefficient for GS: 0.131, p-value: 0.000
# Pearson correlation coefficient for mp_raptor: 0.122, p-value: 0.000
# Pearson correlation coefficient for W_nba: 0.122, p-value: 0.000
# Pearson correlation coefficient for poss_raptor: 0.122, p-value: 0.000
# Pearson correlation coefficient for predator_total_raptor: 0.116, p-value: 0.000
# Pearson correlation coefficient for raptor_defense_raptor: 0.115, p-value: 0.000
# Pearson correlation coefficient for MP_100_poss: 0.115, p-value: 0.000
# Pearson correlation coefficient for MP_advanced: 0.115, p-value: 0.000
# Pearson correlation coefficient for STL_nba: 0.111, p-value: 0.000
# Pearson correlation coefficient for DRtg_100_poss: -0.109, p-value: 0.000
# Pearson correlation coefficient for raptor_total_raptor: 0.107, p-value: 0.000
# Pearson correlation coefficient for %BLK_nba: 0.106, p-value: 0.000
# Pearson correlation coefficient for MIN_nba: 0.103, p-value: 0.000
# Pearson correlation coefficient for MPG_espn: 0.103, p-value: 0.000
# Pearson correlation coefficient for STL: 0.102, p-value: 0.000
# Pearson correlation coefficient for MP: 0.102, p-value: 0.000
# Pearson correlation coefficient for DBPM_advanced: 0.096, p-value: 0.000
# Pearson correlation coefficient for BLK%_advanced: 0.096, p-value: 0.000
# Pearson correlation coefficient for DREB%_nba: 0.094, p-value: 0.000
# Pearson correlation coefficient for BLK_100_poss: 0.094, p-value: 0.000
# Pearson correlation coefficient for DRB_100_poss: 0.094, p-value: 0.000
# Pearson correlation coefficient for DRB%_advanced: 0.090, p-value: 0.000
# Pearson correlation coefficient for %DREB_nba: 0.088, p-value: 0.000
# Pearson correlation coefficient for PER_advanced: 0.088, p-value: 0.000
# Pearson correlation coefficient for OPP PTS OFF TOV_nba: 0.087, p-value: 0.000
# Pearson correlation coefficient for OPP PTS PAINT_nba: 0.087, p-value: 0.000
# Pearson correlation coefficient for OPP PTS 2ND CHANCE_nba: 0.086, p-value: 0.000
# Pearson correlation coefficient for MOV_misc: 0.086, p-value: 0.000
# Pearson correlation coefficient for TOV: 0.085, p-value: 0.000
# Pearson correlation coefficient for SRS_misc: 0.085, p-value: 0.000
# Pearson correlation coefficient for PW_misc: 0.084, p-value: 0.000
# Pearson correlation coefficient for W_misc: 0.082, p-value: 0.000
# Pearson correlation coefficient for PL_misc: -0.081, p-value: 0.000
# Pearson correlation coefficient for OPP PTS FB_nba: 0.081, p-value: 0.000
# Pearson correlation coefficient for TRB_100_poss: 0.081, p-value: 0.000
# Pearson correlation coefficient for WS/48_advanced: 0.080, p-value: 0.000
# Pearson correlation coefficient for TRB%_advanced: 0.080, p-value: 0.000
# Pearson correlation coefficient for L_misc: -0.079, p-value: 0.000
# Pearson correlation coefficient for GP_espn: 0.074, p-value: 0.000
# Pearson correlation coefficient for GP_nba: 0.074, p-value: 0.000
# Pearson correlation coefficient for G: 0.074, p-value: 0.000
# Pearson correlation coefficient for PF: 0.074, p-value: 0.000
# Pearson correlation coefficient for FG%_opponent: -0.069, p-value: 0.000
# Pearson correlation coefficient for DRtg_misc: -0.066, p-value: 0.000
# Pearson correlation coefficient for BPM_advanced: 0.049, p-value: 0.000
# Pearson correlation coefficient for BLK_team: 0.046, p-value: 0.000
# Pearson correlation coefficient for 2P%_opponent: -0.046, p-value: 0.000
# Pearson correlation coefficient for SOS_misc: -0.045, p-value: 0.000
# Pearson correlation coefficient for DRB%_misc: 0.043, p-value: 0.000
# Pearson correlation coefficient for AST_opponent: -0.041, p-value: 0.000
# Pearson correlation coefficient for 3P%_opponent: -0.041, p-value: 0.000
# Pearson correlation coefficient for DRB_team: 0.039, p-value: 0.000
# Pearson correlation coefficient for STL%_nba: 0.038, p-value: 0.000
# Pearson correlation coefficient for FT_opponent: -0.032, p-value: 0.000
# Pearson correlation coefficient for FTA_opponent: -0.031, p-value: 0.000
# Pearson correlation coefficient for PF_100_poss: -0.030, p-value: 0.000
# Pearson correlation coefficient for ORB_opponent: -0.024, p-value: 0.002
# Pearson correlation coefficient for PF_team: -0.024, p-value: 0.002
# Pearson correlation coefficient for TRB_team: 0.024, p-value: 0.003
# Pearson correlation coefficient for pace_impact_raptor: -0.022, p-value: 0.004
# Pearson correlation coefficient for DEF RTG_nba: 0.022, p-value: 0.005
# Pearson correlation coefficient for 2P_opponent: -0.020, p-value: 0.012
# Pearson correlation coefficient for STL_100_poss: 0.019, p-value: 0.015
# Pearson correlation coefficient for STL%_advanced: 0.019, p-value: 0.015
# Pearson correlation coefficient for AST_team: 0.015, p-value: 0.055
# Pearson correlation coefficient for TRB_opponent: -0.012, p-value: 0.119
# Pearson correlation coefficient for teamates_with_dpoy: 0.011, p-value: 0.179
# Pearson correlation coefficient for TOV_team: -0.010, p-value: 0.212
# Pearson correlation coefficient for TOV%_misc: -0.008, p-value: 0.281
# Pearson correlation coefficient for TOV_100_poss: 0.006, p-value: 0.425
# Pearson correlation coefficient for Pace_misc: -0.005, p-value: 0.502
# Pearson correlation coefficient for Age: 0.005, p-value: 0.503
# Pearson correlation coefficient for FGA_opponent: 0.005, p-value: 0.527
# Pearson correlation coefficient for STL_team: 0.004, p-value: 0.602
# Pearson correlation coefficient for FT%_opponent: -0.004, p-value: 0.634
# Pearson correlation coefficient for 3PA_opponent: 0.003, p-value: 0.692
# Pearson correlation coefficient for TOV%.1_misc: -0.003, p-value: 0.721
# Pearson correlation coefficient for 3P_opponent: -0.002, p-value: 0.792
# Pearson correlation coefficient for 2PA_opponent: 0.002, p-value: 0.821

# %%
all_players_w_add_sorted = pd.read_csv("all_players_w_add_sorted.csv")

# covert to intger
all_players_w_add_sorted['Year'] = pd.to_numeric(all_players_w_add_sorted['Year'], errors='coerce')

# Create subsets for each 5-year interval
subset_1993_1997 = all_players_w_add_sorted[(all_players_w_add_sorted['Year'] >= 1993) & (all_players_w_add_sorted['Year'] <= 1997)]
subset_1998_2002 = all_players_w_add_sorted[(all_players_w_add_sorted['Year'] >= 1998) & (all_players_w_add_sorted['Year'] <= 2002)]
subset_2003_2007 = all_players_w_add_sorted[(all_players_w_add_sorted['Year'] >= 2003) & (all_players_w_add_sorted['Year'] <= 2007)]
subset_2008_2012 = all_players_w_add_sorted[(all_players_w_add_sorted['Year'] >= 2008) & (all_players_w_add_sorted['Year'] <= 2012)]
subset_2013_2017 = all_players_w_add_sorted[(all_players_w_add_sorted['Year'] >= 2013) & (all_players_w_add_sorted['Year'] <= 2017)]
subset_2018_2023 = all_players_w_add_sorted[(all_players_w_add_sorted['Year'] >= 2018) & (all_players_w_add_sorted['Year'] <= 2023)]
# Out:
# C:\Users\Abdou\AppData\Local\Temp\ipykernel_9968\3088546698.py:1: DtypeWarning: Columns (154,155) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_players_w_add_sorted = pd.read_csv("all_players_w_add_sorted.csv")

# %%
show_PersonsR(subset_1993_1997,"1993_1997")
# Out:
# DataFrame does not contain missing values or empty strings/spaces.
# Pearson correlation coefficient for Dpoy_titles: 0.618, p-value: 0.000
# Pearson correlation coefficient for Dpoy_votes: 0.511, p-value: 0.000
# Pearson correlation coefficient for DWS_advanced: 0.300, p-value: 0.000
# Pearson correlation coefficient for VORP_advanced: 0.294, p-value: 0.000
# Pearson correlation coefficient for war_total_raptor: 0.294, p-value: 0.000
# Pearson correlation coefficient for BLK: 0.288, p-value: 0.000
# Pearson correlation coefficient for war_reg_season_raptor: 0.277, p-value: 0.000
# Pearson correlation coefficient for WS_advanced: 0.258, p-value: 0.000
# Pearson correlation coefficient for DRB: 0.208, p-value: 0.000
# Pearson correlation coefficient for TRB: 0.194, p-value: 0.000
# Pearson correlation coefficient for mp_raptor: 0.168, p-value: 0.000
# Pearson correlation coefficient for raptor_defense_raptor: 0.165, p-value: 0.000
# Pearson correlation coefficient for poss_raptor: 0.164, p-value: 0.000
# Pearson correlation coefficient for predator_defense_raptor: 0.157, p-value: 0.000
# Pearson correlation coefficient for STL: 0.154, p-value: 0.000
# Pearson correlation coefficient for MP_100_poss: 0.153, p-value: 0.000
# Pearson correlation coefficient for MP_advanced: 0.153, p-value: 0.000
# Pearson correlation coefficient for GS: 0.146, p-value: 0.000
# Pearson correlation coefficient for DRtg_100_poss: -0.143, p-value: 0.000
# Pearson correlation coefficient for predator_total_raptor: 0.141, p-value: 0.000
# Pearson correlation coefficient for TOV: 0.139, p-value: 0.000
# Pearson correlation coefficient for raptor_total_raptor: 0.139, p-value: 0.000
# Pearson correlation coefficient for MP: 0.137, p-value: 0.000
# Pearson correlation coefficient for PER_advanced: 0.127, p-value: 0.000
# Pearson correlation coefficient for BPM_advanced: 0.116, p-value: 0.000
# Pearson correlation coefficient for WINS_espn: 0.111, p-value: 0.000
# Pearson correlation coefficient for DRPM_espn: 0.109, p-value: 0.000
# Pearson correlation coefficient for WS/48_advanced: 0.103, p-value: 0.000
# Pearson correlation coefficient for DRB_100_poss: 0.097, p-value: 0.000
# Pearson correlation coefficient for PF: 0.097, p-value: 0.000
# Pearson correlation coefficient for DBPM_advanced: 0.095, p-value: 0.000
# Pearson correlation coefficient for BLK_nba: 0.090, p-value: 0.000
# Pearson correlation coefficient for W_misc: 0.088, p-value: 0.000
# Pearson correlation coefficient for L_misc: -0.088, p-value: 0.000
# Pearson correlation coefficient for DRtg_misc: -0.087, p-value: 0.000
# Pearson correlation coefficient for DRB%_advanced: 0.087, p-value: 0.000
# Pearson correlation coefficient for BLK_100_poss: 0.087, p-value: 0.000
# Pearson correlation coefficient for G: 0.086, p-value: 0.000
# Pearson correlation coefficient for PW_misc: 0.086, p-value: 0.000
# Pearson correlation coefficient for PL_misc: -0.086, p-value: 0.000
# Pearson correlation coefficient for MOV_misc: 0.085, p-value: 0.000
# Pearson correlation coefficient for SRS_misc: 0.085, p-value: 0.000
# Pearson correlation coefficient for BLK%_advanced: 0.083, p-value: 0.000
# Pearson correlation coefficient for RPM_espn: 0.082, p-value: 0.000
# Pearson correlation coefficient for FG%_opponent: -0.079, p-value: 0.000
# Pearson correlation coefficient for 2P%_opponent: -0.078, p-value: 0.000
# Pearson correlation coefficient for TRB_100_poss: 0.077, p-value: 0.000
# Pearson correlation coefficient for TRB%_advanced: 0.075, p-value: 0.000
# Pearson correlation coefficient for DEF WS_nba: 0.066, p-value: 0.002
# Pearson correlation coefficient for pace_impact_raptor: -0.064, p-value: 0.002
# Pearson correlation coefficient for SOS_misc: -0.062, p-value: 0.003
# Pearson correlation coefficient for DRB_team: 0.058, p-value: 0.006
# Pearson correlation coefficient for AST_opponent: -0.057, p-value: 0.007
# Pearson correlation coefficient for FTA_opponent: -0.055, p-value: 0.009
# Pearson correlation coefficient for FT_opponent: -0.055, p-value: 0.009
# Pearson correlation coefficient for DREB_nba: 0.052, p-value: 0.012
# Pearson correlation coefficient for TRB_opponent: -0.048, p-value: 0.021
# Pearson correlation coefficient for PF_100_poss: -0.044, p-value: 0.035
# Pearson correlation coefficient for BLK_team: 0.044, p-value: 0.036
# Pearson correlation coefficient for PF_team: -0.041, p-value: 0.050
# Pearson correlation coefficient for Age: 0.040, p-value: 0.053
# Pearson correlation coefficient for W_nba: 0.039, p-value: 0.062
# Pearson correlation coefficient for STL_team: 0.039, p-value: 0.062
# Pearson correlation coefficient for 3P%_opponent: -0.039, p-value: 0.063
# Pearson correlation coefficient for DRB%_misc: 0.039, p-value: 0.064
# Pearson correlation coefficient for %BLK_nba: 0.039, p-value: 0.065
# Pearson correlation coefficient for STL_nba: 0.036, p-value: 0.084
# Pearson correlation coefficient for MPG_espn: 0.034, p-value: 0.107
# Pearson correlation coefficient for STL_100_poss: 0.034, p-value: 0.109
# Pearson correlation coefficient for STL%_advanced: 0.034, p-value: 0.109
# Pearson correlation coefficient for 2P_opponent: -0.033, p-value: 0.113
# Pearson correlation coefficient for MIN_nba: 0.033, p-value: 0.115
# Pearson correlation coefficient for OPP PTS 2ND CHANCE_nba: 0.031, p-value: 0.136
# Pearson correlation coefficient for Pace_misc: -0.027, p-value: 0.194
# Pearson correlation coefficient for teamates_with_dpoy: 0.024, p-value: 0.257
# Pearson correlation coefficient for OPP PTS OFF TOV_nba: 0.023, p-value: 0.262
# Pearson correlation coefficient for TRB_team: 0.023, p-value: 0.275
# Pearson correlation coefficient for OPP PTS PAINT_nba: 0.022, p-value: 0.283
# Pearson correlation coefficient for GP_espn: 0.021, p-value: 0.325
# Pearson correlation coefficient for GP_nba: 0.020, p-value: 0.345
# Pearson correlation coefficient for OPP PTS FB_nba: 0.019, p-value: 0.352
# Pearson correlation coefficient for DREB%_nba: 0.015, p-value: 0.472
# Pearson correlation coefficient for TOV_team: -0.015, p-value: 0.477
# Pearson correlation coefficient for %DREB_nba: 0.014, p-value: 0.517
# Pearson correlation coefficient for TOV_100_poss: 0.012, p-value: 0.557
# Pearson correlation coefficient for 3PA_opponent: 0.011, p-value: 0.615
# Pearson correlation coefficient for FT%_opponent: -0.010, p-value: 0.633
# Pearson correlation coefficient for ORB_opponent: -0.010, p-value: 0.647
# Pearson correlation coefficient for TOV%.1_misc: 0.009, p-value: 0.674
# Pearson correlation coefficient for 2PA_opponent: -0.007, p-value: 0.721
# Pearson correlation coefficient for AST_team: 0.007, p-value: 0.740
# Pearson correlation coefficient for TOV%_misc: 0.004, p-value: 0.862
# Pearson correlation coefficient for FGA_opponent: -0.003, p-value: 0.884
# Pearson correlation coefficient for DEF RTG_nba: -0.002, p-value: 0.925
# Pearson correlation coefficient for 3P_opponent: 0.001, p-value: 0.972
# Pearson correlation coefficient for STL%_nba: 0.000, p-value: 0.985
# Pearson correlation coefficient for D-LEBRON_bball: nan, p-value: nan
# c:\users\abdou\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
show_PersonsR(subset_1998_2002,"1998_2002")
# Out:
# DataFrame does not contain missing values or empty strings/spaces.
# Pearson correlation coefficient for Dpoy_titles: 0.461, p-value: 0.000
# Pearson correlation coefficient for Dpoy_votes: 0.320, p-value: 0.000
# Pearson correlation coefficient for BLK_nba: 0.309, p-value: 0.000
# Pearson correlation coefficient for BLK: 0.307, p-value: 0.000
# Pearson correlation coefficient for WINS_espn: 0.227, p-value: 0.000
# Pearson correlation coefficient for DWS_advanced: 0.214, p-value: 0.000
# Pearson correlation coefficient for DREB_nba: 0.205, p-value: 0.000
# Pearson correlation coefficient for war_total_raptor: 0.204, p-value: 0.000
# Pearson correlation coefficient for DRB: 0.203, p-value: 0.000
# Pearson correlation coefficient for TRB: 0.202, p-value: 0.000
# Pearson correlation coefficient for DRPM_espn: 0.200, p-value: 0.000
# Pearson correlation coefficient for VORP_advanced: 0.190, p-value: 0.000
# Pearson correlation coefficient for war_reg_season_raptor: 0.187, p-value: 0.000
# Pearson correlation coefficient for WS_advanced: 0.183, p-value: 0.000
# Pearson correlation coefficient for BLK_100_poss: 0.169, p-value: 0.000
# Pearson correlation coefficient for BLK%_advanced: 0.163, p-value: 0.000
# Pearson correlation coefficient for RPM_espn: 0.163, p-value: 0.000
# Pearson correlation coefficient for DEF WS_nba: 0.153, p-value: 0.000
# Pearson correlation coefficient for raptor_defense_raptor: 0.152, p-value: 0.000
# Pearson correlation coefficient for %BLK_nba: 0.146, p-value: 0.000
# Pearson correlation coefficient for mp_raptor: 0.131, p-value: 0.000
# Pearson correlation coefficient for predator_defense_raptor: 0.129, p-value: 0.000
# Pearson correlation coefficient for poss_raptor: 0.127, p-value: 0.000
# Pearson correlation coefficient for DRtg_100_poss: -0.116, p-value: 0.000
# Pearson correlation coefficient for DREB%_nba: 0.113, p-value: 0.000
# Pearson correlation coefficient for GS: 0.111, p-value: 0.000
# Pearson correlation coefficient for MIN_nba: 0.110, p-value: 0.000
# Pearson correlation coefficient for MP: 0.110, p-value: 0.000
# Pearson correlation coefficient for %DREB_nba: 0.108, p-value: 0.000
# Pearson correlation coefficient for MPG_espn: 0.108, p-value: 0.000
# Pearson correlation coefficient for MP_100_poss: 0.105, p-value: 0.000
# Pearson correlation coefficient for MP_advanced: 0.105, p-value: 0.000
# Pearson correlation coefficient for DRB%_advanced: 0.104, p-value: 0.000
# Pearson correlation coefficient for OPP PTS OFF TOV_nba: 0.098, p-value: 0.000
# Pearson correlation coefficient for TRB%_advanced: 0.096, p-value: 0.000
# Pearson correlation coefficient for TRB_100_poss: 0.095, p-value: 0.000
# Pearson correlation coefficient for DRB_100_poss: 0.094, p-value: 0.000
# Pearson correlation coefficient for raptor_total_raptor: 0.094, p-value: 0.000
# Pearson correlation coefficient for predator_total_raptor: 0.093, p-value: 0.000
# Pearson correlation coefficient for PER_advanced: 0.093, p-value: 0.000
# Pearson correlation coefficient for OPP PTS 2ND CHANCE_nba: 0.092, p-value: 0.000
# Pearson correlation coefficient for W_nba: 0.090, p-value: 0.000
# Pearson correlation coefficient for TOV: 0.085, p-value: 0.000
# Pearson correlation coefficient for BPM_advanced: 0.082, p-value: 0.000
# Pearson correlation coefficient for DBPM_advanced: 0.082, p-value: 0.000
# Pearson correlation coefficient for OPP PTS PAINT_nba: 0.079, p-value: 0.000
# Pearson correlation coefficient for pace_impact_raptor: -0.077, p-value: 0.000
# Pearson correlation coefficient for OPP PTS FB_nba: 0.077, p-value: 0.000
# Pearson correlation coefficient for PF: 0.073, p-value: 0.000
# Pearson correlation coefficient for WS/48_advanced: 0.072, p-value: 0.000
# Pearson correlation coefficient for GP_espn: 0.065, p-value: 0.001
# Pearson correlation coefficient for GP_nba: 0.065, p-value: 0.001
# Pearson correlation coefficient for STL_nba: 0.060, p-value: 0.003
# Pearson correlation coefficient for 2P%_opponent: -0.059, p-value: 0.004
# Pearson correlation coefficient for STL: 0.057, p-value: 0.005
# Pearson correlation coefficient for G: 0.056, p-value: 0.006
# Pearson correlation coefficient for FG%_opponent: -0.052, p-value: 0.011
# Pearson correlation coefficient for DRtg_misc: -0.051, p-value: 0.013
# Pearson correlation coefficient for MOV_misc: 0.050, p-value: 0.014
# Pearson correlation coefficient for W_misc: 0.049, p-value: 0.016
# Pearson correlation coefficient for SRS_misc: 0.048, p-value: 0.018
# Pearson correlation coefficient for L_misc: -0.046, p-value: 0.024
# Pearson correlation coefficient for PW_misc: 0.046, p-value: 0.025
# Pearson correlation coefficient for PL_misc: -0.043, p-value: 0.036
# Pearson correlation coefficient for BLK_team: 0.039, p-value: 0.055
# Pearson correlation coefficient for Pace_misc: -0.039, p-value: 0.060
# Pearson correlation coefficient for PF_100_poss: -0.036, p-value: 0.075
# Pearson correlation coefficient for SOS_misc: -0.034, p-value: 0.092
# Pearson correlation coefficient for FTA_opponent: -0.028, p-value: 0.168
# Pearson correlation coefficient for FT_opponent: -0.027, p-value: 0.186
# Pearson correlation coefficient for Age: 0.025, p-value: 0.220
# Pearson correlation coefficient for AST_opponent: -0.022, p-value: 0.275
# Pearson correlation coefficient for DRB%_misc: 0.021, p-value: 0.312
# Pearson correlation coefficient for TOV%.1_misc: -0.014, p-value: 0.492
# Pearson correlation coefficient for PF_team: -0.014, p-value: 0.509
# Pearson correlation coefficient for STL_100_poss: -0.013, p-value: 0.524
# Pearson correlation coefficient for STL%_advanced: -0.013, p-value: 0.524
# Pearson correlation coefficient for teamates_with_dpoy: -0.011, p-value: 0.603
# Pearson correlation coefficient for 3P_opponent: -0.010, p-value: 0.612
# Pearson correlation coefficient for DRB_team: 0.010, p-value: 0.613
# Pearson correlation coefficient for 3PA_opponent: -0.009, p-value: 0.651
# Pearson correlation coefficient for STL_team: -0.009, p-value: 0.657
# Pearson correlation coefficient for 2P_opponent: -0.007, p-value: 0.737
# Pearson correlation coefficient for TOV%_misc: 0.006, p-value: 0.757
# Pearson correlation coefficient for STL%_nba: -0.005, p-value: 0.808
# Pearson correlation coefficient for TOV_team: -0.005, p-value: 0.810
# Pearson correlation coefficient for FT%_opponent: 0.005, p-value: 0.817
# Pearson correlation coefficient for TRB_opponent: -0.005, p-value: 0.826
# Pearson correlation coefficient for 2PA_opponent: 0.004, p-value: 0.827
# Pearson correlation coefficient for DEF RTG_nba: 0.004, p-value: 0.847
# Pearson correlation coefficient for 3P%_opponent: -0.004, p-value: 0.855
# Pearson correlation coefficient for TOV_100_poss: -0.003, p-value: 0.886
# Pearson correlation coefficient for FGA_opponent: 0.002, p-value: 0.923
# Pearson correlation coefficient for TRB_team: 0.001, p-value: 0.962
# Pearson correlation coefficient for ORB_opponent: -0.001, p-value: 0.971
# Pearson correlation coefficient for AST_team: 0.000, p-value: 0.991
# Pearson correlation coefficient for D-LEBRON_bball: nan, p-value: nan
# c:\users\abdou\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
show_PersonsR(subset_2003_2007,"2003_2007")
# Out:
# DataFrame does not contain missing values or empty strings/spaces.
# Pearson correlation coefficient for Dpoy_titles: 0.321, p-value: 0.000
# Pearson correlation coefficient for Dpoy_votes: 0.318, p-value: 0.000
# Pearson correlation coefficient for DWS_advanced: 0.314, p-value: 0.000
# Pearson correlation coefficient for BLK_nba: 0.292, p-value: 0.000
# Pearson correlation coefficient for BLK: 0.282, p-value: 0.000
# Pearson correlation coefficient for raptor_defense_raptor: 0.266, p-value: 0.000
# Pearson correlation coefficient for war_total_raptor: 0.247, p-value: 0.000
# Pearson correlation coefficient for predator_defense_raptor: 0.239, p-value: 0.000
# Pearson correlation coefficient for war_reg_season_raptor: 0.223, p-value: 0.000
# Pearson correlation coefficient for DRB: 0.222, p-value: 0.000
# Pearson correlation coefficient for DREB_nba: 0.222, p-value: 0.000
# Pearson correlation coefficient for DRPM_espn: 0.216, p-value: 0.000
# Pearson correlation coefficient for TRB: 0.213, p-value: 0.000
# Pearson correlation coefficient for DEF WS_nba: 0.212, p-value: 0.000
# Pearson correlation coefficient for WINS_espn: 0.211, p-value: 0.000
# Pearson correlation coefficient for VORP_advanced: 0.208, p-value: 0.000
# Pearson correlation coefficient for WS_advanced: 0.186, p-value: 0.000
# Pearson correlation coefficient for mp_raptor: 0.167, p-value: 0.000
# Pearson correlation coefficient for STL_nba: 0.165, p-value: 0.000
# Pearson correlation coefficient for poss_raptor: 0.162, p-value: 0.000
# Pearson correlation coefficient for STL: 0.162, p-value: 0.000
# Pearson correlation coefficient for GS: 0.159, p-value: 0.000
# Pearson correlation coefficient for DBPM_advanced: 0.151, p-value: 0.000
# Pearson correlation coefficient for predator_total_raptor: 0.149, p-value: 0.000
# Pearson correlation coefficient for RPM_espn: 0.149, p-value: 0.000
# Pearson correlation coefficient for raptor_total_raptor: 0.148, p-value: 0.000
# Pearson correlation coefficient for BLK_100_poss: 0.146, p-value: 0.000
# Pearson correlation coefficient for DRtg_100_poss: -0.145, p-value: 0.000
# Pearson correlation coefficient for W_nba: 0.144, p-value: 0.000
# Pearson correlation coefficient for MP_100_poss: 0.144, p-value: 0.000
# Pearson correlation coefficient for MP_advanced: 0.144, p-value: 0.000
# Pearson correlation coefficient for BLK%_advanced: 0.142, p-value: 0.000
# Pearson correlation coefficient for MP: 0.134, p-value: 0.000
# Pearson correlation coefficient for MIN_nba: 0.134, p-value: 0.000
# Pearson correlation coefficient for MPG_espn: 0.134, p-value: 0.000
# Pearson correlation coefficient for OPP PTS PAINT_nba: 0.121, p-value: 0.000
# Pearson correlation coefficient for DRB_100_poss: 0.121, p-value: 0.000
# Pearson correlation coefficient for %BLK_nba: 0.120, p-value: 0.000
# Pearson correlation coefficient for OPP PTS 2ND CHANCE_nba: 0.116, p-value: 0.000
# Pearson correlation coefficient for DRB%_advanced: 0.116, p-value: 0.000
# Pearson correlation coefficient for DREB%_nba: 0.113, p-value: 0.000
# Pearson correlation coefficient for %DREB_nba: 0.111, p-value: 0.000
# Pearson correlation coefficient for OPP PTS FB_nba: 0.109, p-value: 0.000
# Pearson correlation coefficient for OPP PTS OFF TOV_nba: 0.107, p-value: 0.000
# Pearson correlation coefficient for PW_misc: 0.106, p-value: 0.000
# Pearson correlation coefficient for PL_misc: -0.106, p-value: 0.000
# Pearson correlation coefficient for MOV_misc: 0.104, p-value: 0.000
# Pearson correlation coefficient for W_misc: 0.103, p-value: 0.000
# Pearson correlation coefficient for L_misc: -0.103, p-value: 0.000
# Pearson correlation coefficient for SRS_misc: 0.100, p-value: 0.000
# Pearson correlation coefficient for TRB_100_poss: 0.098, p-value: 0.000
# Pearson correlation coefficient for pace_impact_raptor: -0.096, p-value: 0.000
# Pearson correlation coefficient for DRtg_misc: -0.096, p-value: 0.000
# Pearson correlation coefficient for TRB%_advanced: 0.095, p-value: 0.000
# Pearson correlation coefficient for 3P_opponent: -0.093, p-value: 0.000
# Pearson correlation coefficient for FT_opponent: -0.090, p-value: 0.000
# Pearson correlation coefficient for FTA_opponent: -0.087, p-value: 0.000
# Pearson correlation coefficient for G: 0.087, p-value: 0.000
# Pearson correlation coefficient for GP_espn: 0.086, p-value: 0.000
# Pearson correlation coefficient for GP_nba: 0.086, p-value: 0.000
# Pearson correlation coefficient for 3PA_opponent: -0.083, p-value: 0.000
# Pearson correlation coefficient for AST_opponent: -0.080, p-value: 0.000
# Pearson correlation coefficient for WS/48_advanced: 0.078, p-value: 0.000
# Pearson correlation coefficient for BLK_team: 0.078, p-value: 0.000
# Pearson correlation coefficient for PF_team: -0.077, p-value: 0.000
# Pearson correlation coefficient for 3P%_opponent: -0.076, p-value: 0.000
# Pearson correlation coefficient for PER_advanced: 0.075, p-value: 0.000
# Pearson correlation coefficient for PF_100_poss: -0.067, p-value: 0.001
# Pearson correlation coefficient for STL%_nba: 0.065, p-value: 0.001
# Pearson correlation coefficient for TOV: 0.058, p-value: 0.004
# Pearson correlation coefficient for PF: 0.058, p-value: 0.004
# Pearson correlation coefficient for 2P%_opponent: -0.058, p-value: 0.004
# Pearson correlation coefficient for FG%_opponent: -0.057, p-value: 0.004
# Pearson correlation coefficient for SOS_misc: -0.054, p-value: 0.007
# Pearson correlation coefficient for Age: 0.046, p-value: 0.022
# Pearson correlation coefficient for DRB%_misc: 0.045, p-value: 0.024
# Pearson correlation coefficient for STL_100_poss: 0.043, p-value: 0.030
# Pearson correlation coefficient for STL%_advanced: 0.043, p-value: 0.030
# Pearson correlation coefficient for AST_team: 0.042, p-value: 0.037
# Pearson correlation coefficient for Pace_misc: -0.040, p-value: 0.046
# Pearson correlation coefficient for TOV_team: -0.039, p-value: 0.052
# Pearson correlation coefficient for 2PA_opponent: 0.039, p-value: 0.054
# Pearson correlation coefficient for DRB_team: 0.038, p-value: 0.055
# Pearson correlation coefficient for TRB_opponent: -0.037, p-value: 0.068
# Pearson correlation coefficient for FT%_opponent: -0.034, p-value: 0.085
# Pearson correlation coefficient for TOV_100_poss: -0.034, p-value: 0.086
# Pearson correlation coefficient for ORB_opponent: -0.030, p-value: 0.132
# Pearson correlation coefficient for TOV%_misc: -0.027, p-value: 0.175
# Pearson correlation coefficient for BPM_advanced: 0.026, p-value: 0.186
# Pearson correlation coefficient for TRB_team: 0.025, p-value: 0.218
# Pearson correlation coefficient for TOV%.1_misc: 0.022, p-value: 0.267
# Pearson correlation coefficient for DEF RTG_nba: 0.016, p-value: 0.426
# Pearson correlation coefficient for FGA_opponent: -0.013, p-value: 0.518
# Pearson correlation coefficient for 2P_opponent: -0.010, p-value: 0.628
# Pearson correlation coefficient for STL_team: -0.001, p-value: 0.978
# Pearson correlation coefficient for teamates_with_dpoy: 0.000, p-value: 0.994
# Pearson correlation coefficient for D-LEBRON_bball: nan, p-value: nan
# c:\users\abdou\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
show_PersonsR(subset_2008_2012,"2008_2012")
# Out:
# DataFrame does not contain missing values or empty strings/spaces.
# Pearson correlation coefficient for DWS_advanced: 0.311, p-value: 0.000
# Pearson correlation coefficient for Dpoy_votes: 0.295, p-value: 0.000
# Pearson correlation coefficient for Dpoy_titles: 0.293, p-value: 0.000
# Pearson correlation coefficient for war_total_raptor: 0.277, p-value: 0.000
# Pearson correlation coefficient for WINS_espn: 0.275, p-value: 0.000
# Pearson correlation coefficient for BLK_nba: 0.269, p-value: 0.000
# Pearson correlation coefficient for VORP_advanced: 0.264, p-value: 0.000
# Pearson correlation coefficient for BLK: 0.263, p-value: 0.000
# Pearson correlation coefficient for war_reg_season_raptor: 0.259, p-value: 0.000
# Pearson correlation coefficient for WS_advanced: 0.254, p-value: 0.000
# Pearson correlation coefficient for raptor_defense_raptor: 0.225, p-value: 0.000
# Pearson correlation coefficient for DREB_nba: 0.223, p-value: 0.000
# Pearson correlation coefficient for DRB: 0.222, p-value: 0.000
# Pearson correlation coefficient for TRB: 0.217, p-value: 0.000
# Pearson correlation coefficient for predator_defense_raptor: 0.202, p-value: 0.000
# Pearson correlation coefficient for RPM_espn: 0.200, p-value: 0.000
# Pearson correlation coefficient for DEF WS_nba: 0.192, p-value: 0.000
# Pearson correlation coefficient for D-LEBRON_bball: 0.191, p-value: 0.000
# Pearson correlation coefficient for DRPM_espn: 0.179, p-value: 0.000
# Pearson correlation coefficient for raptor_total_raptor: 0.175, p-value: 0.000
# Pearson correlation coefficient for predator_total_raptor: 0.167, p-value: 0.000
# Pearson correlation coefficient for GS: 0.152, p-value: 0.000
# Pearson correlation coefficient for mp_raptor: 0.151, p-value: 0.000
# Pearson correlation coefficient for poss_raptor: 0.149, p-value: 0.000
# Pearson correlation coefficient for DRtg_100_poss: -0.139, p-value: 0.000
# Pearson correlation coefficient for TOV: 0.138, p-value: 0.000
# Pearson correlation coefficient for MP_100_poss: 0.137, p-value: 0.000
# Pearson correlation coefficient for MP_advanced: 0.137, p-value: 0.000
# Pearson correlation coefficient for W_nba: 0.134, p-value: 0.000
# Pearson correlation coefficient for PER_advanced: 0.127, p-value: 0.000
# Pearson correlation coefficient for DRB_100_poss: 0.126, p-value: 0.000
# Pearson correlation coefficient for STL_nba: 0.125, p-value: 0.000
# Pearson correlation coefficient for BPM_advanced: 0.122, p-value: 0.000
# Pearson correlation coefficient for STL: 0.120, p-value: 0.000
# Pearson correlation coefficient for DBPM_advanced: 0.120, p-value: 0.000
# Pearson correlation coefficient for DREB%_nba: 0.119, p-value: 0.000
# Pearson correlation coefficient for MP: 0.119, p-value: 0.000
# Pearson correlation coefficient for MIN_nba: 0.118, p-value: 0.000
# Pearson correlation coefficient for WS/48_advanced: 0.117, p-value: 0.000
# Pearson correlation coefficient for MPG_espn: 0.117, p-value: 0.000
# Pearson correlation coefficient for DRB%_advanced: 0.117, p-value: 0.000
# Pearson correlation coefficient for %BLK_nba: 0.117, p-value: 0.000
# Pearson correlation coefficient for %DREB_nba: 0.109, p-value: 0.000
# Pearson correlation coefficient for OPP PTS OFF TOV_nba: 0.107, p-value: 0.000
# Pearson correlation coefficient for BLK_100_poss: 0.107, p-value: 0.000
# Pearson correlation coefficient for BLK%_advanced: 0.106, p-value: 0.000
# Pearson correlation coefficient for DRtg_misc: -0.106, p-value: 0.000
# Pearson correlation coefficient for FG%_opponent: -0.104, p-value: 0.000
# Pearson correlation coefficient for TRB_100_poss: 0.103, p-value: 0.000
# Pearson correlation coefficient for 2P%_opponent: -0.103, p-value: 0.000
# Pearson correlation coefficient for TRB%_advanced: 0.102, p-value: 0.000
# Pearson correlation coefficient for PF: 0.099, p-value: 0.000
# Pearson correlation coefficient for OPP PTS 2ND CHANCE_nba: 0.098, p-value: 0.000
# Pearson correlation coefficient for MOV_misc: 0.097, p-value: 0.000
# Pearson correlation coefficient for PL_misc: -0.094, p-value: 0.000
# Pearson correlation coefficient for PW_misc: 0.094, p-value: 0.000
# Pearson correlation coefficient for SRS_misc: 0.094, p-value: 0.000
# Pearson correlation coefficient for OPP PTS PAINT_nba: 0.089, p-value: 0.000
# Pearson correlation coefficient for G: 0.089, p-value: 0.000
# Pearson correlation coefficient for L_misc: -0.088, p-value: 0.000
# Pearson correlation coefficient for W_misc: 0.088, p-value: 0.000
# Pearson correlation coefficient for GP_nba: 0.081, p-value: 0.000
# Pearson correlation coefficient for GP_espn: 0.080, p-value: 0.000
# Pearson correlation coefficient for OPP PTS FB_nba: 0.078, p-value: 0.000
# Pearson correlation coefficient for SOS_misc: -0.072, p-value: 0.000
# Pearson correlation coefficient for DRB%_misc: 0.072, p-value: 0.000
# Pearson correlation coefficient for pace_impact_raptor: -0.063, p-value: 0.001
# Pearson correlation coefficient for FT%_opponent: -0.055, p-value: 0.005
# Pearson correlation coefficient for 3P%_opponent: -0.053, p-value: 0.007
# Pearson correlation coefficient for AST_opponent: -0.053, p-value: 0.007
# Pearson correlation coefficient for DRB_team: 0.042, p-value: 0.034
# Pearson correlation coefficient for STL%_nba: 0.041, p-value: 0.038
# Pearson correlation coefficient for 2P_opponent: -0.036, p-value: 0.068
# Pearson correlation coefficient for TOV_100_poss: 0.033, p-value: 0.088
# Pearson correlation coefficient for 3P_opponent: -0.032, p-value: 0.105
# Pearson correlation coefficient for BLK_team: 0.032, p-value: 0.105
# Pearson correlation coefficient for PF_100_poss: -0.031, p-value: 0.113
# Pearson correlation coefficient for TOV%_misc: 0.031, p-value: 0.115
# Pearson correlation coefficient for ORB_opponent: -0.030, p-value: 0.128
# Pearson correlation coefficient for STL_100_poss: 0.030, p-value: 0.131
# Pearson correlation coefficient for STL%_advanced: 0.030, p-value: 0.131
# Pearson correlation coefficient for FT_opponent: -0.029, p-value: 0.143
# Pearson correlation coefficient for TRB_opponent: -0.024, p-value: 0.221
# Pearson correlation coefficient for FTA_opponent: -0.023, p-value: 0.241
# Pearson correlation coefficient for TRB_team: 0.019, p-value: 0.327
# Pearson correlation coefficient for Pace_misc: -0.016, p-value: 0.413
# Pearson correlation coefficient for 3PA_opponent: -0.016, p-value: 0.424
# Pearson correlation coefficient for AST_team: -0.015, p-value: 0.431
# Pearson correlation coefficient for TOV%.1_misc: 0.014, p-value: 0.481
# Pearson correlation coefficient for PF_team: -0.013, p-value: 0.509
# Pearson correlation coefficient for DEF RTG_nba: 0.012, p-value: 0.542
# Pearson correlation coefficient for STL_team: 0.010, p-value: 0.607
# Pearson correlation coefficient for FGA_opponent: -0.006, p-value: 0.751
# Pearson correlation coefficient for TOV_team: 0.006, p-value: 0.778
# Pearson correlation coefficient for 2PA_opponent: -0.002, p-value: 0.921
# Pearson correlation coefficient for Age: 0.002, p-value: 0.936
# Pearson correlation coefficient for teamates_with_dpoy: 0.000, p-value: 0.983

# %%
show_PersonsR(subset_2013_2017,"2013_2017")
# Out:
# DataFrame does not contain missing values or empty strings/spaces.
# Pearson correlation coefficient for war_total_raptor: 0.310, p-value: 0.000
# Pearson correlation coefficient for DWS_advanced: 0.297, p-value: 0.000
# Pearson correlation coefficient for war_reg_season_raptor: 0.291, p-value: 0.000
# Pearson correlation coefficient for Dpoy_titles: 0.275, p-value: 0.000
# Pearson correlation coefficient for VORP_advanced: 0.261, p-value: 0.000
# Pearson correlation coefficient for D-LEBRON_bball: 0.248, p-value: 0.000
# Pearson correlation coefficient for WS_advanced: 0.244, p-value: 0.000
# Pearson correlation coefficient for BLK_nba: 0.236, p-value: 0.000
# Pearson correlation coefficient for WINS_espn: 0.232, p-value: 0.000
# Pearson correlation coefficient for BLK: 0.225, p-value: 0.000
# Pearson correlation coefficient for DEF WS_nba: 0.202, p-value: 0.000
# Pearson correlation coefficient for DREB_nba: 0.201, p-value: 0.000
# Pearson correlation coefficient for DRB: 0.194, p-value: 0.000
# Pearson correlation coefficient for TRB: 0.189, p-value: 0.000
# Pearson correlation coefficient for DRPM_espn: 0.168, p-value: 0.000
# Pearson correlation coefficient for RPM_espn: 0.167, p-value: 0.000
# Pearson correlation coefficient for predator_total_raptor: 0.163, p-value: 0.000
# Pearson correlation coefficient for GS: 0.155, p-value: 0.000
# Pearson correlation coefficient for predator_defense_raptor: 0.154, p-value: 0.000
# Pearson correlation coefficient for mp_raptor: 0.153, p-value: 0.000
# Pearson correlation coefficient for Dpoy_votes: 0.152, p-value: 0.000
# Pearson correlation coefficient for poss_raptor: 0.151, p-value: 0.000
# Pearson correlation coefficient for DRtg_100_poss: -0.149, p-value: 0.000
# Pearson correlation coefficient for W_nba: 0.149, p-value: 0.000
# Pearson correlation coefficient for STL_nba: 0.148, p-value: 0.000
# Pearson correlation coefficient for STL: 0.143, p-value: 0.000
# Pearson correlation coefficient for raptor_total_raptor: 0.143, p-value: 0.000
# Pearson correlation coefficient for MP_100_poss: 0.139, p-value: 0.000
# Pearson correlation coefficient for MP_advanced: 0.139, p-value: 0.000
# Pearson correlation coefficient for DBPM_advanced: 0.124, p-value: 0.000
# Pearson correlation coefficient for raptor_defense_raptor: 0.122, p-value: 0.000
# Pearson correlation coefficient for MIN_nba: 0.120, p-value: 0.000
# Pearson correlation coefficient for MPG_espn: 0.120, p-value: 0.000
# Pearson correlation coefficient for MP: 0.120, p-value: 0.000
# Pearson correlation coefficient for BPM_advanced: 0.119, p-value: 0.000
# Pearson correlation coefficient for MOV_misc: 0.118, p-value: 0.000
# Pearson correlation coefficient for SRS_misc: 0.117, p-value: 0.000
# Pearson correlation coefficient for DRtg_misc: -0.116, p-value: 0.000
# Pearson correlation coefficient for L_misc: -0.115, p-value: 0.000
# Pearson correlation coefficient for W_misc: 0.115, p-value: 0.000
# Pearson correlation coefficient for PW_misc: 0.115, p-value: 0.000
# Pearson correlation coefficient for PL_misc: -0.115, p-value: 0.000
# Pearson correlation coefficient for BLK_100_poss: 0.108, p-value: 0.000
# Pearson correlation coefficient for FG%_opponent: -0.107, p-value: 0.000
# Pearson correlation coefficient for PF: 0.104, p-value: 0.000
# Pearson correlation coefficient for OPP PTS 2ND CHANCE_nba: 0.104, p-value: 0.000
# Pearson correlation coefficient for OPP PTS PAINT_nba: 0.103, p-value: 0.000
# Pearson correlation coefficient for 2P%_opponent: -0.103, p-value: 0.000
# Pearson correlation coefficient for WS/48_advanced: 0.103, p-value: 0.000
# Pearson correlation coefficient for BLK%_advanced: 0.102, p-value: 0.000
# Pearson correlation coefficient for PER_advanced: 0.102, p-value: 0.000
# Pearson correlation coefficient for OPP PTS FB_nba: 0.100, p-value: 0.000
# Pearson correlation coefficient for DREB%_nba: 0.096, p-value: 0.000
# Pearson correlation coefficient for DRB_100_poss: 0.095, p-value: 0.000
# Pearson correlation coefficient for %BLK_nba: 0.094, p-value: 0.000
# Pearson correlation coefficient for TOV: 0.094, p-value: 0.000
# Pearson correlation coefficient for OPP PTS OFF TOV_nba: 0.093, p-value: 0.000
# Pearson correlation coefficient for BLK_team: 0.092, p-value: 0.000
# Pearson correlation coefficient for %DREB_nba: 0.091, p-value: 0.000
# Pearson correlation coefficient for G: 0.090, p-value: 0.000
# Pearson correlation coefficient for AST_team: 0.089, p-value: 0.000
# Pearson correlation coefficient for DRB%_advanced: 0.088, p-value: 0.000
# Pearson correlation coefficient for TRB_100_poss: 0.084, p-value: 0.000
# Pearson correlation coefficient for TRB%_advanced: 0.083, p-value: 0.000
# Pearson correlation coefficient for 3P%_opponent: -0.083, p-value: 0.000
# Pearson correlation coefficient for GP_nba: 0.081, p-value: 0.000
# Pearson correlation coefficient for GP_espn: 0.081, p-value: 0.000
# Pearson correlation coefficient for AST_opponent: -0.074, p-value: 0.000
# Pearson correlation coefficient for 3P_opponent: -0.068, p-value: 0.000
# Pearson correlation coefficient for DRB_team: 0.053, p-value: 0.005
# Pearson correlation coefficient for TRB_opponent: -0.050, p-value: 0.009
# Pearson correlation coefficient for 3PA_opponent: -0.049, p-value: 0.010
# Pearson correlation coefficient for 2PA_opponent: 0.045, p-value: 0.019
# Pearson correlation coefficient for STL_100_poss: 0.043, p-value: 0.024
# Pearson correlation coefficient for STL%_advanced: 0.043, p-value: 0.024
# Pearson correlation coefficient for STL%_nba: 0.040, p-value: 0.035
# Pearson correlation coefficient for PF_team: -0.040, p-value: 0.036
# Pearson correlation coefficient for FT_opponent: -0.037, p-value: 0.052
# Pearson correlation coefficient for FTA_opponent: -0.036, p-value: 0.062
# Pearson correlation coefficient for SOS_misc: -0.036, p-value: 0.063
# Pearson correlation coefficient for STL_team: 0.033, p-value: 0.086
# Pearson correlation coefficient for TRB_team: 0.032, p-value: 0.100
# Pearson correlation coefficient for 2P_opponent: -0.027, p-value: 0.160
# Pearson correlation coefficient for DRB%_misc: 0.026, p-value: 0.170
# Pearson correlation coefficient for PF_100_poss: -0.021, p-value: 0.285
# Pearson correlation coefficient for TOV%.1_misc: 0.019, p-value: 0.335
# Pearson correlation coefficient for Age: -0.015, p-value: 0.445
# Pearson correlation coefficient for TOV_team: -0.014, p-value: 0.474
# Pearson correlation coefficient for Pace_misc: -0.013, p-value: 0.514
# Pearson correlation coefficient for TOV_100_poss: 0.012, p-value: 0.545
# Pearson correlation coefficient for DEF RTG_nba: 0.012, p-value: 0.548
# Pearson correlation coefficient for FT%_opponent: -0.010, p-value: 0.618
# Pearson correlation coefficient for teamates_with_dpoy: 0.004, p-value: 0.853
# Pearson correlation coefficient for pace_impact_raptor: 0.004, p-value: 0.854
# Pearson correlation coefficient for TOV%_misc: -0.003, p-value: 0.866
# Pearson correlation coefficient for FGA_opponent: -0.003, p-value: 0.868
# Pearson correlation coefficient for ORB_opponent: -0.001, p-value: 0.961

# %%
show_PersonsR(subset_2018_2023,"2018_2023")
# Out:
# DataFrame does not contain missing values or empty strings/spaces.
# Pearson correlation coefficient for Dpoy_titles: 0.341, p-value: 0.000
# Pearson correlation coefficient for BLK_nba: 0.259, p-value: 0.000
# Pearson correlation coefficient for DWS_advanced: 0.251, p-value: 0.000
# Pearson correlation coefficient for BLK: 0.247, p-value: 0.000
# Pearson correlation coefficient for D-LEBRON_bball: 0.234, p-value: 0.000
# Pearson correlation coefficient for WS_advanced: 0.224, p-value: 0.000
# Pearson correlation coefficient for VORP_advanced: 0.214, p-value: 0.000
# Pearson correlation coefficient for war_total_raptor: 0.211, p-value: 0.000
# Pearson correlation coefficient for WINS_espn: 0.209, p-value: 0.000
# Pearson correlation coefficient for Dpoy_votes: 0.209, p-value: 0.000
# Pearson correlation coefficient for war_reg_season_raptor: 0.204, p-value: 0.000
# Pearson correlation coefficient for DREB_nba: 0.199, p-value: 0.000
# Pearson correlation coefficient for DRB: 0.191, p-value: 0.000
# Pearson correlation coefficient for TRB: 0.189, p-value: 0.000
# Pearson correlation coefficient for DEF WS_nba: 0.186, p-value: 0.000
# Pearson correlation coefficient for RPM_espn: 0.168, p-value: 0.000
# Pearson correlation coefficient for DRPM_espn: 0.153, p-value: 0.000
# Pearson correlation coefficient for GS: 0.142, p-value: 0.000
# Pearson correlation coefficient for DRtg_100_poss: -0.122, p-value: 0.000
# Pearson correlation coefficient for W_nba: 0.121, p-value: 0.000
# Pearson correlation coefficient for MP_100_poss: 0.118, p-value: 0.000
# Pearson correlation coefficient for MP_advanced: 0.118, p-value: 0.000
# Pearson correlation coefficient for %BLK_nba: 0.115, p-value: 0.000
# Pearson correlation coefficient for BLK_100_poss: 0.113, p-value: 0.000
# Pearson correlation coefficient for TOV: 0.108, p-value: 0.000
# Pearson correlation coefficient for BLK%_advanced: 0.107, p-value: 0.000
# Pearson correlation coefficient for poss_raptor: 0.104, p-value: 0.000
# Pearson correlation coefficient for mp_raptor: 0.103, p-value: 0.000
# Pearson correlation coefficient for PF: 0.102, p-value: 0.000
# Pearson correlation coefficient for MIN_nba: 0.100, p-value: 0.000
# Pearson correlation coefficient for MPG_espn: 0.099, p-value: 0.000
# Pearson correlation coefficient for DRB_100_poss: 0.098, p-value: 0.000
# Pearson correlation coefficient for MP: 0.098, p-value: 0.000
# Pearson correlation coefficient for DREB%_nba: 0.096, p-value: 0.000
# Pearson correlation coefficient for PER_advanced: 0.094, p-value: 0.000
# Pearson correlation coefficient for predator_total_raptor: 0.092, p-value: 0.000
# Pearson correlation coefficient for 2P%_opponent: -0.090, p-value: 0.000
# Pearson correlation coefficient for DRB%_advanced: 0.090, p-value: 0.000
# Pearson correlation coefficient for FG%_opponent: -0.090, p-value: 0.000
# Pearson correlation coefficient for MOV_misc: 0.089, p-value: 0.000
# Pearson correlation coefficient for SRS_misc: 0.089, p-value: 0.000
# Pearson correlation coefficient for TRB_100_poss: 0.089, p-value: 0.000
# Pearson correlation coefficient for DRtg_misc: -0.089, p-value: 0.000
# Pearson correlation coefficient for %DREB_nba: 0.088, p-value: 0.000
# Pearson correlation coefficient for OPP PTS OFF TOV_nba: 0.088, p-value: 0.000
# Pearson correlation coefficient for predator_defense_raptor: 0.087, p-value: 0.000
# Pearson correlation coefficient for PL_misc: -0.087, p-value: 0.000
# Pearson correlation coefficient for TRB%_advanced: 0.086, p-value: 0.000
# Pearson correlation coefficient for PW_misc: 0.085, p-value: 0.000
# Pearson correlation coefficient for STL_nba: 0.084, p-value: 0.000
# Pearson correlation coefficient for L_misc: -0.081, p-value: 0.000
# Pearson correlation coefficient for G: 0.081, p-value: 0.000
# Pearson correlation coefficient for DBPM_advanced: 0.080, p-value: 0.000
# Pearson correlation coefficient for W_misc: 0.080, p-value: 0.000
# Pearson correlation coefficient for WS/48_advanced: 0.079, p-value: 0.000
# Pearson correlation coefficient for STL: 0.079, p-value: 0.000
# Pearson correlation coefficient for OPP PTS FB_nba: 0.078, p-value: 0.000
# Pearson correlation coefficient for raptor_total_raptor: 0.077, p-value: 0.000
# Pearson correlation coefficient for OPP PTS PAINT_nba: 0.077, p-value: 0.000
# Pearson correlation coefficient for OPP PTS 2ND CHANCE_nba: 0.075, p-value: 0.000
# Pearson correlation coefficient for GP_espn: 0.071, p-value: 0.000
# Pearson correlation coefficient for GP_nba: 0.071, p-value: 0.000
# Pearson correlation coefficient for BPM_advanced: 0.069, p-value: 0.000
# Pearson correlation coefficient for DRB%_misc: 0.068, p-value: 0.000
# Pearson correlation coefficient for raptor_defense_raptor: 0.066, p-value: 0.000
# Pearson correlation coefficient for DRB_team: 0.060, p-value: 0.000
# Pearson correlation coefficient for BLK_team: 0.052, p-value: 0.001
# Pearson correlation coefficient for TRB_team: 0.049, p-value: 0.003
# Pearson correlation coefficient for SOS_misc: -0.049, p-value: 0.003
# Pearson correlation coefficient for AST_opponent: -0.045, p-value: 0.006
# Pearson correlation coefficient for pace_impact_raptor: 0.038, p-value: 0.018
# Pearson correlation coefficient for 3P%_opponent: -0.038, p-value: 0.020
# Pearson correlation coefficient for TOV_100_poss: 0.033, p-value: 0.042
# Pearson correlation coefficient for FT_opponent: -0.025, p-value: 0.124
# Pearson correlation coefficient for Pace_misc: 0.025, p-value: 0.131
# Pearson correlation coefficient for FT%_opponent: -0.023, p-value: 0.163
# Pearson correlation coefficient for FTA_opponent: -0.022, p-value: 0.182
# Pearson correlation coefficient for 2P_opponent: -0.022, p-value: 0.183
# Pearson correlation coefficient for STL_team: 0.020, p-value: 0.226
# Pearson correlation coefficient for TOV_team: 0.019, p-value: 0.254
# Pearson correlation coefficient for TOV%_misc: 0.018, p-value: 0.277
# Pearson correlation coefficient for ORB_opponent: -0.018, p-value: 0.278
# Pearson correlation coefficient for AST_team: 0.018, p-value: 0.278
# Pearson correlation coefficient for TRB_opponent: -0.017, p-value: 0.310
# Pearson correlation coefficient for 2PA_opponent: 0.016, p-value: 0.315
# Pearson correlation coefficient for 3P_opponent: -0.016, p-value: 0.327
# Pearson correlation coefficient for teamates_with_dpoy: 0.015, p-value: 0.367
# Pearson correlation coefficient for FGA_opponent: 0.012, p-value: 0.461
# Pearson correlation coefficient for STL%_nba: 0.010, p-value: 0.532
# Pearson correlation coefficient for PF_team: -0.008, p-value: 0.604
# Pearson correlation coefficient for PF_100_poss: -0.008, p-value: 0.643
# Pearson correlation coefficient for DEF RTG_nba: 0.006, p-value: 0.731
# Pearson correlation coefficient for TOV%.1_misc: -0.004, p-value: 0.784
# Pearson correlation coefficient for 3PA_opponent: -0.003, p-value: 0.843
# Pearson correlation coefficient for STL_100_poss: 0.002, p-value: 0.910
# Pearson correlation coefficient for STL%_advanced: 0.002, p-value: 0.910
# Pearson correlation coefficient for Age: 0.001, p-value: 0.943
